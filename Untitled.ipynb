# %% [markdown]
#   ** TIME SERIES ANALYSIS FOR REAL ESTATE INVESTMENTS**

# %% [markdown]
# ![Alt text](image-1.png)

# %% [markdown]
# **INTRODUCTION**
#
# Real estate refers to physical property consisting of land, buildings, and any natural resources found on or beneath the land's surface. It is a tangible asset that encompasses a wide range of properties, including residential homes, commercial buildings, industrial facilities, vacant land, and more. Real estate is a fundamental component of the economy and plays a significant role in various aspects of society, including housing, commerce, and investment.Real estate is a valuable asset class that can appreciate in value over time, generate rental income, and provide a hedge against inflation. It is also a common investment choice for individuals and institutions looking to diversify their portfolios. The real estate market can be influenced by factors such as supply and demand, economic conditions, interest rates, and government policies.

# %% [markdown]
# **Statement of problem**
#
# Real estate constitutes a substantial portion of wealth for many individuals, particularly homeowners in the United States. The dynamics of the real estate market are influenced by a multitude of factors, including government policies, demographic trends among potential buyers, affordability considerations, disparities in housing access, geographic location, cash flow prospects, liquidity conditions, and the prevailing economic environment. The interplay of these numerous variables often complicates the decision-making process for prospective buyers. To address this complexity, Apex Consultants aims to develop a predictive time series model capable of identifying the top five zip codes for strategic real estate investments.

# %% [markdown]
# **Main Objectives**
#
# 1. To develop a time series model that would predict the top five zipcodes to invest in
#
#
# **Specific Objectives**
#
# 1. To serve as a consulting partner for Apex Consultant  Firm, offering well-informed recommendations on the top five zip codes for investment opportunities.
#
# 2. To analyze and track historical trends in house price returns to understand how they have evolved over time.

# %% [markdown]
# **Data Understanding**
#
# The dataset used in this study was obtained from Zillow Research Website and has 14,723 rows and 272 columns. The representation of each and every column present in our dataset is discussed below:
#
# RegionID - shows the unique ID of each region and it is an integer(int64) data type.
#
# RegionName - shows the name of the region by zipcode and it is an integer(int64) data type.
#
# City - shows the city where the region is located which is of string data type.
#
# State - shows the state where the region is located and it is of string(object) data type.
#
# Metro - shows the metropolitan area where the region is located (if applicable).
#
# CountyName - shows the name of the county where the region is located.It is a string (object) data type.
#
# SizeRank - shows the relative size of the region compared to other regions in the datase and it is an integer (int64) data type.
#
# 1996 upto 2018 - 	depicts the median home price for the region in months and years. It is a float (float64) data type.

# %% [markdown]
# **Importing the libraries**
#
# In the cell below we will import the python libraries and modules that will be relevant for our study

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

from sklearn.metrics import mean_squared_error
import statsmodels.api as sm
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.tsa.stattools import adfuller
from statsmodels.graphics.tsaplots import plot_acf,plot_pacf
import pmdarima as pm
from statsmodels.tsa.arima.model import ARIMA
from statsmodels.tsa.statespace.sarimax import SARIMAX
from sklearn.metrics import mean_squared_error as MSE
from math import sqrt
from matplotlib.pylab import rcParams

# %% [markdown]
# **Load the data**
#
# We will then load the pandas dataframe and make sure to display all the columns

# %%
# displaying all columns
pd.set_option("display.max_columns",None)
df= pd.read_csv('zillow_data.csv')
df.head()  #To display the first 5 rows of our dataset
# Out:
#    RegionID  RegionName      City State              Metro CountyName
# 0     84654       60657   Chicago    IL            Chicago       Cook  \
# 1     90668       75070  McKinney    TX  Dallas-Fort Worth     Collin
# 2     91982       77494      Katy    TX            Houston     Harris
# 3     84616       60614   Chicago    IL            Chicago       Cook
# 4     93144       79936   El Paso    TX            El Paso    El Paso
#
#    SizeR
# 14721   569100   575800   581700   585400   590700   588000   592500   615900
# 14722   314900   315900   317000   318400   320100   322000   324700   328000
#
#        2017-06  2017-07  2017-08  2017-09  2017-10  2017-11  2017-12  2018-01
# 14718   215400   216800   217700   218600   218500   218100   216400   213100  \
# 14719   197300   202100   208400   212200   215200   214300   213100   213700
# 14720   121100   121800   122800   124600   126700   128800   130600   131700
# 14721   647300   662800   671200   682400   695600   695500   694700   706400
# 14722   331300   333800   336400   339700   343800   346800   348900   350400
#
#        2018-02  2018-03  2018-04
# 14718   209800   209200   209300
# 14719   218300   222700   225800
# 14720   132500   133000   133400
# 14721   705300   681500   664400
# 14722   353000   356000   357200

# %% [markdown]
# **Feature Engineering**
#
# We will create two new columns called ROI and %ROI which is the known return on investment.The return on investment allows one to measure the profitability of an investment.It is calculated by dividing the net profit( or loss) from an investment by its cost.A positive return on investment indicates that the investment has been profitable whereas a negative return on investment indicates that the investment has not been profitable
#
#
# ROI is a useful metric for evaluating different investment opportunities. It can help you to identify investments that are likely to be profitable and to avoid investments that are likely to be unprofitable. ROI can also be used to compare the performance of different investments over time.
#
# Generally, ROI is a valuable metric that can be used to measure the profitability of an investment and to make better investment decisions.

# %%
# creating a column of actual ROI
df['ROI'] = df["2018-04"] - df["2012-01"]-1

# creating a column of %ROI
df["%ROI"] = ((df["2018-04"] / df["2012-01"]) ** (1 / (2018-2012)) - 1) * 100

# %% [markdown]
# We will also rename the column 'RegionName' to 'Zipcode' and 'value' will be renamed as 'Price'

# %%
# rename RegionID to zipcode
df = df.rename(columns={'RegionName': 'Zipcode','value':'Price'})

# %%
df.head()
# Out:
#    RegionID  Zipcode      City State              Metro CountyName  SizeRank
# 0     84654    60657   Chicago    IL            Chicago       Cook         1  \
# 1     90668    75070  McKinney    TX  Dallas-Fort Worth     Collin         2
# 2     91982    77494      Katy    TX            Houston     Harris         3
# 3     84616    60614   Chicago    IL            Chicago       Cook         4
# 4     93144    79936   El Paso    TX            El Paso    El Paso         5
#
#     1996-04   1996-05   1996-06   1996-07   1996-08   1996-09   1996-10
# 0  334200.0  335400.0  336500.0  337600.0  338500.0  339500.0  340400.0  \
# 1  235700.0  236900.0  236700.0  235400.0  233300.0  230600.0  227300.0
# 2  210400.0  212200.0  212200.0  210700.0  208300.0  205500.0  202500.0
# 3  498100.0  500900.0  503100.0  504600.0  505500.0  505700.0  505300.0
# 4   77300.0   77300.0   77300.0   77300.0   77400.0   77500.0   77600.0
#
#     1996-11   1996-12   1997-01   1997-02   1997-03   1997-04   1997-05
# 0  341300.0  342600.0  344400.0  345700.0  346700.0  347800.0  349000.0  \
# 1  223400.0  219600.0  215800.0  211100.0  205700.0  200900.0  196800.0
# 2  199800.0  198300.0  197300.0  195400.0  193000.0  191800.0  191800.0
# 3  504200.0  503600.0  503400.0  502200.0  500000.0  497900.0  496300.0
# 4   77700.0   77700.0   77800.0   77900.0   77900.0   77800.0   77800.0
#
#     1997-06   1997-07   1997-08   1997-09   1997-10   1997-11   1997-12
# 0  350400.0  352000.0  353900.0  356200.0  358800.0  361800.0  365700.0  \
017-09  2017-10  2017-11  2017-12  2018-01  2018-02  2018-03  2018-04
# 0  1007800  1009600  1013300  1018700  1024400  1030700  1033800  1030600  \
# 1   312500   314100   315000   316600   318100   319600   321100   321800
# 2   320200   320400   320800   321200   321200   323000   326900   329900
# 3  1287400  1291500  1296600  1299000  1302700  1306400  1308500  1307000
# 4   120000   120300   120300   120300   120300   120500   121000   121500
#
#         ROI      %ROI
# 0  292899.0  5.730851
# 1  122199.0  8.285652
# 2   81299.0  4.828700
# 3  378099.0  5.856559
# 4    9099.0  1.305960

# %% [markdown]
# **Data Cleaning and Preparation**
#
# To facilitate a comprehensive exploration of our dataset, we have defined several custom functions:
#
# transform_to_long_format(df): converts our dataframe from a wide to long format
#
# data_shape(df): This function reveals the shape of the DataFrame, providing the number of rows and columns in the dataset.
#
# data_info(df): Offering valuable insights, this function presents information about the data, such as column names, data types, and the count of non-null values in each column.
#
# data_missing(df): With a focus on data completeness, this function detects the presence of missing values by examining each column for null entries. If no missing values are found, a message indicating their absence is displayed.
#
# identify_duplicates(df): This function pinpoints and provides details about duplicate rows in the dataset. It computes the count and percentage of duplicated rows present. In case no duplicates exist, it conveys a message confirming their non existence.

# %%
# convert wide format to long format
df = pd.melt(df, 
               id_vars=['RegionID','Zipcode', 'SizeRank', 'City', 'State', 'Metro', 'CountyName','%ROI','ROI'], 
               var_name='Date')

# rename RegionID to zipcode
df = df.rename(columns={'RegionName': 'Zipcode','value':'Price'})

#convert zipcode to categorical datatype
df['Zipcode'] = df['Zipcode'].astype('str')

# convert date to datetime
df['Date'] = pd.to_datetime(df['Date'],format='%Y-%m')

df.head()
# Out:
#    RegionID Zipcode  SizeRank      City State              Metro CountyName
# 0     84654   60657         1   Chicago    IL            Chicago       Cook  \
# 1     90668   75070         2  McKinney    TX  Dallas-Fort Worth     Collin
# 2     91982   77494         3      Katy    TX            Houston     Harris
# 3     84616   60614         4   Chicago    IL            Chicago       Cook
# 4     93144   79936         5   El Paso    TX            El Paso    El Paso
#
#        %ROI       ROI       Date     Price
# 0  5.730851  292899.0 1996-04-01  334200.0
# 1  8.285652  122199.0 1996-04-01  235700.0
# 2  4.828700   81299.0 1996-04-01  210400.0
# 3  5.856559  378099.0 1996-04-01  498100.0
# 4  1.305960    9099.0 1996-04-01   77300.0

# %%
# Function to print the shape of the DataFrame
def data_shape(df):
    print("Data Shape:")
    print(f"Number of Rows: {df.shape[0]}")
    print(f"Number of Columns: {df.shape[1]}\n")

# Function to display information about the data
def data_info(df):
    print("Data Information:")
    print(df.iloc[:,:8].info())  #tis will display the top 8 columns and their data types

# Function to check for missing values
def data_missing(df):
    print("\nMissing Values:")
    print(df.isnull().sum())

   # Function to identify and display duplicate rows
def identify_duplicates(df):
    duplicates = df[df.duplicated()]
    print("\nDuplicate Rows:")
    print(duplicates)

# %%
# Function to explore the dataset
def explore_dataset(df):
    data_shape(df)
    data_info(df)
    data_missing(df)
    identify_duplicates(df)

# %%
df.columns
# Out:
# Index(['RegionID', 'Zipcode', 'SizeRank', 'City', 'State', 'Metro',
#        'CountyName', '%ROI', 'ROI', 'Date', 'Price'],
#       dtype='object')

# %%
# Call the fuction to explore the dataset
explore_dataset(df)
# Out:
# Data Shape:
# Number of Rows: 3901595
# Number of Columns: 11
#
# Data Information:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3901595 entries, 0 to 3901594
# Data columns (total 8 columns):
#  #   Column      Dtype
# ---  ------      -----
#  0   RegionID    int64
#  1   Zipcode     object
#  2   SizeRank    int64
#  3   City        object
#  4   State       object
#  5   Metro       object
#  6   CountyName  object
#  7   %ROI        float64
# dtypes: float64(1), int64(2), object(5)
# memory usage: 238.1+ MB
# None
#
# Missing Values:
# RegionID           0
# Zipcode            0
# SizeRank           0
# City               0
# State              0
# Metro         276395
# CountyName         0
# %ROI           59360
# ROI            59360
# Date               0
# Price         156891
# dtype: int64
#
# Duplicate Rows:
# Empty DataFrame
# Columns: [RegionID, Zipcode, SizeRank, City, State, Metro, CountyName, %ROI, ROI, Date, Price]
# Index: []

# %% [markdown]
# We can observe that 'Metro' column has 1043 missing values and we will ipute the missing values as shown below

# %%
# filling missing values 
df['Metro'].fillna('Missing',inplace = True)

# %%
df.head()
# Out:
#    RegionID Zipcode  SizeRank      City State              Metro CountyName
# 0     84654   60657         1   Chicago    IL            Chicago       Cook  \
# 1     90668   75070         2  McKinney    TX  Dallas-Fort Worth     Collin
# 2     91982   77494         3      Katy    TX            Houston     Harris
# 3     84616   60614         4   Chicago    IL            Chicago       Cook
# 4     93144   79936         5   El Paso    TX            El Paso    El Paso
#
#        %ROI       ROI       Date     Price
# 0  5.730851  292899.0 1996-04-01  334200.0
# 1  8.285652  122199.0 1996-04-01  235700.0
# 2  4.828700   81299.0 1996-04-01  210400.0
# 3  5.856559  378099.0 1996-04-01  498100.0
# 4  1.305960    9099.0 1996-04-01   77300.0

# %% [markdown]
# Also from our dataset we can observe that there are no duplicate entries since it results an empty dataframe of duplicate entries

# %% [markdown]
# **EXPLORATORY DATA ANALYSIS**
#
# 1.**Univariate Analysis**
#
# **What are the top 10 most popular Counties?**

# %%
# Get the top 10 most popular counties
top_counties = df['CountyName'].value_counts().head(10)

# Create a horizontal bar plot
plt.figure(figsize=(12, 8))
top_counties.plot(kind="barh", color='green')  # You can change the color if desired

# Add labels and a title
plt.xlabel("Count", fontsize=15)
plt.ylabel("County Name", fontsize=15)
plt.title("Top 10 Most Popular Counties", fontsize=20)

# Display the count values on the bars
for index, value in enumerate(top_counties):
    plt.text(value, index, f" {value}", fontsize=12, va='center')

plt.gca().invert_yaxis()  # Invert the y-axis to have the most popular county at the top

plt.show()

# %% [markdown]
# From the horizontal bar graph above we can observe that Los Angeles is the most popular county with a count of 264 whereas Maricopa is the least popular with a count of 111.

# %% [markdown]
# **What are the top 10 Most popular States?**

# %%
# Get the top 10 most popular states
top_states = df['State'].value_counts().head(10)

# Create a bar plot
plt.figure(figsize=(12, 8))
top_states.plot(kind="bar", color='green')  # You can change the color if desired

# Add labels and a title
plt.xlabel("Count", fontsize=15)
plt.ylabel("US States", fontsize=15)
plt.xticks(rotation=0)
plt.title("Top 10 Most Popular States", fontsize=20)

# Display the count values on top of the bars
for x, y in enumerate(top_states):
    plt.text(x, y, f" {y}", fontsize=12, va='bottom', ha='center')

plt.show()

# %% [markdown]
# We can observe that California is the most popular state with a count of 1224 whereas Indiana state is the least popular with a count of 428.

# %% [markdown]
# **What are the top 10 Most Popular Cities?**

# %%
# Get the top 10 most popular cities
top_cities = df['City'].value_counts().head(10)

# Create a vertical bar plot
plt.figure(figsize=(12, 8))
top_cities.plot(kind="bar", color='green')  # You can change the color if desired

# Add labels and a title
plt.xlabel("US Cities", fontsize=15)
plt.ylabel("Count", fontsize=15)
plt.xticks(rotation=45, ha="right")
plt.title("Top 10 Most Popular Cities", fontsize=20)

# Display the count values on top of the bars
for x, y in enumerate(top_cities):
    plt.text(x, y, f" {y}", fontsize=12, va='bottom', ha='center')

plt.show()

# %% [markdown]
# New York is the most popular city whereas Philadelphia is the least popular city in the United States

# %% [markdown]
# 2.**Bivariate Analysis**

# %% [markdown]
# **What is the mean percentage return on investment by zipcode?**

# %%
# grouping data by mean %ROI and selecting top 30 zipcodes
grouped1 = df.groupby('Zipcode')
state_values1 = grouped1['%ROI'].mean()
state_values_df1 = state_values1.reset_index(name='% ROI')
state_values_df1 = state_values_df1.sort_values(by='% ROI', ascending=False)
top_twenty_zipcodes_df_roi = state_values_df1.head(20)

# %%
plt.figure(figsize=(15, 8))
sns.barplot(x='Zipcode', y='% ROI', data=top_twenty_zipcodes_df_roi, color='green')
plt.xlabel('Zipcode', fontsize=15)
plt.ylabel('% ROI', fontsize=15)
plt.title('% ROI by Zipcode', fontsize=20)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# From the graph above we can observe taht zipcode 85035 seems to be the most profitable zipcode at 22.8% ROI from 2012 to 2018

# %% [markdown]
# **What is the change in house prices from 1996 to 2018?**

# %%
# creating a data series to check the prices of houses over time
ts = df.copy()
ts.set_index("Date",inplace=True)
ts = ts["Price"]

# %%
# Resample the time series data
resampled_data = ts.resample("A").mean().reset_index()

# Set the Seaborn style
sns.set(style="whitegrid")

# Create the plot using Seaborn
plt.figure(figsize=(15, 10))
sns.lineplot(x="Date", y="Price", data=resampled_data)
plt.ylabel("Mean Price", fontsize=15)
plt.title("Plot of Mean House Price from 1996 to 2018 in USA", fontsize=20)

# Rotate x-axis labels for better readability
plt.xticks(rotation=45)

plt.show()

# %% [markdown]
# The housing market exhibited a clear trend between 1996 and 2008, with house prices steadily increasing. However, this upward trajectory was abruptly disrupted by the housing market crash, resulting in a sharp and significant decline in house prices. The market eventually stabilized around 2012. Following this stabilization, house prices began a gradual ascent once again, continuing this upward trend until 2018.

# %% [markdown]
# **What is the mean price of houses by state?**

# %%
# grouping data by mean price and selecting top 30 states
grouped = df.groupby('State')
state_values = grouped['Price'].mean()
state_values_df = state_values.reset_index(name='mean_value')
state_values_df = state_values_df.sort_values(by='mean_value', ascending=False)
top_twenty_states_df = state_values_df.head(20)

# %%
# Set the Seaborn style
sns.set(style="whitegrid")

plt.figure(figsize=(15, 8))
sns.barplot(x='State', y='mean_value', data=top_twenty_states_df, color='green')
plt.xlabel('State', fontsize=15)
plt.ylabel('Mean Value', fontsize=15)
plt.title('Mean Value by State', fontsize=20)

# Rotate x-axis labels for better readability
plt.xticks(rotation=45)

plt.show()

# %% [markdown]
# From the graph above we can observe that Washington DC had the highest mean value by state

# %% [markdown]
# **DATA PREPROCESSING**
#
# When working with time series models, we typically assume that the data is stationary, meaning that the statistical properties such as mean, variance, and autocorrelation do not change over time for each lag. This assumption of stationarity is essential for efficient model development.
#
# To ensure the data's stationarity before modeling, two common approaches are employed. First, the Dickey-Fuller test is conducted to formally assess stationarity. Second, the rolling mean is examined visually to detect any trends or patterns that might indicate non-stationarity.
#
# In cases where the data is found to be non-stationary, differencing is applied as a common technique to transform it into a stationary form, thus meeting the requisite conditions for time series modeling.

# %%
non_numeric_prices = df[~df['Price'].apply(pd.to_numeric, errors='coerce').notna()]
if not non_numeric_prices.empty:
    print("Non-numeric values found in the 'Price' column:")
    print(non_numeric_prices)
# Out:
# Non-numeric values found in the 'Price' column:
#          RegionID Zipcode  SizeRank          City State          Metro
# 20          61625   10011        21      New York    NY       New York  \
# 36          61796   10456        37      New York    NY       New York
# 105         84613   60611       106       Chicago    IL        Chicago
# 156         62048   11238       157      New York    NY       New York
# 232         69533   27834       233    Greenville    NC     Greenville
# ...           ...     ...       ...           ...   ...            ...
# 3223821     85339   62215     14208        Albers    IL      St. Louis
# 3223881     79020   48157     14268     Luna Pier    MI         Monroe
# 3223955     79832   49636     14342    Glen Arbor    MI  Traverse City
# 3224191     85489   62440     14578         Lerna    IL     Charleston
# 3224321     69681   28039     14708  East Spencer    NC      Charlotte
#
#         CountyName       %ROI        ROI       Date  Price
# 20        New York   8.325609  4374499.0 1996-04-01    NaN
# 36           Bronx        NaN        NaN 1996-04-01    NaN
# 105           Cook        NaN        NaN 1996-04-01    NaN
# 156          Kings  14.645758  1614599.0 1996-04-01    NaN
# 232           Pitt   1.327692     7699.0 1996-04-01    NaN
# ...            ...        ...        ...        ...    ...
# 3223821    Clinton        NaN        NaN 2014-06-01    NaN
# 3223881     Monroe        NaN        NaN 2014-06-01    NaN
# 3223955   Leelanau        NaN        NaN 2014-06-01    NaN
# 3224191      Coles        NaN        NaN 2014-06-01    NaN
# 3224321      Rowan        NaN        NaN 2014-06-01    NaN
#
# [156891 rows x 11 columns]

# %%
# Step 1: Remove rows with non-numeric 'Price' values
df = df[df['Price'].apply(pd.to_numeric, errors='coerce').notna()]

# Step 2: Convert the 'Price' column to numeric data type
df['Price'] = pd.to_numeric(df['Price'])

# Display the updated DataFrame
print(df.head())
# Out:
#    RegionID Zipcode  SizeRank      City State              Metro CountyName
# 0     84654   60657         1   Chicago    IL            Chicago       Cook  \
# 1     90668   75070         2  McKinney    TX  Dallas-Fort Worth     Collin
# 2     91982   77494         3      Katy    TX            Houston     Harris
# 3     84616   60614         4   Chicago    IL            Chicago       Cook
# 4     93144   79936         5   El Paso    TX            El Paso    El Paso
#
#        %ROI       ROI       Date     Price
# 0  5.730851  292899.0 1996-04-01  334200.0
# 1  8.285652  122199.0 1996-04-01  235700.0
# 2  4.828700   81299.0 1996-04-01  210400.0
# 3  5.856559  378099.0 1996-04-01  498100.0
# 4  1.305960    9099.0 1996-04-01   77300.0
# C:\Users\PC\AppData\Local\Temp\ipykernel_5720\3312815533.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Price'] = pd.to_numeric(df['Price'])

# %%
# Step 1: Remove rows with non-numeric '%ROI' values
df = df[df['%ROI'].apply(pd.to_numeric, errors='coerce').notna()]

# Step 2: Convert the '%ROI' column to a numeric data type
df['%ROI'] = pd.to_numeric(df['%ROI'])

# Display the updated DataFrame
print(df.head())
# Out:
#    RegionID Zipcode  SizeRank      City State              Metro CountyName
# 0     84654   60657         1   Chicago    IL            Chicago       Cook  \
# 1     90668   75070         2  McKinney    TX  Dallas-Fort Worth     Collin
# 2     91982   77494         3      Katy    TX            Houston     Harris
# 3     84616   60614         4   Chicago    IL            Chicago       Cook
# 4     93144   79936         5   El Paso    TX            El Paso    El Paso
#
#        %ROI       ROI       Date     Price
# 0  5.730851  292899.0 1996-04-01  334200.0
# 1  8.285652  122199.0 1996-04-01  235700.0
# 2  4.828700   81299.0 1996-04-01  210400.0
# 3  5.856559  378099.0 1996-04-01  498100.0
# 4  1.305960    9099.0 1996-04-01   77300.0

# %%
# Filter data for the top 5 zipcodes based on %ROI
top_5_zipcodes = df.sort_values('%ROI', ascending=False)['Zipcode'].unique()[:5]
filtered_df = df[df['Zipcode'].isin(top_5_zipcodes)]

# Select data from 2005-01-01 onwards
final_df = filtered_df[filtered_df['Date'] >= "2005-01-01"]

# Display the result
final_df.head()
# Out:
#          RegionID Zipcode  SizeRank      City State          Metro
# 1546389     94724   85008       475   Phoenix    AZ        Phoenix  \
# 1547154     97795   94590      1240   Vallejo    CA        Vallejo
# 1547392     97803   94601      1478   Oakland    CA  San Francisco
# 1547768     97850   94804      1854  Richmond    CA  San Francisco
# 1561112     94724   85008       475   Phoenix    AZ        Phoenix
#
#            CountyName       %ROI       ROI       Date     Price
# 1546389      Maricopa  21.534560  153799.0 2005-01-01  147400.0
# 1547154        Solano  20.822042  255199.0 2005-01-01  368800.0
# 1547392       Alameda  20.829750  384599.0 2005-01-01  398200.0
# 1547768  Contra Costa  21.468835  332699.0 2005-01-01  445300.0
# 1561112      Maricopa  21.534560  153799.0 2005-02-01  150700.0

# %% [markdown]
# We then create a dataframe to check the change over price in time for the top five zipcodes

# %%
top_5 = final_df.drop(['RegionID', 'SizeRank', '%ROI', 'ROI'],axis=1)

top_5 = top_5.set_index('Date')
print('Time series data for the 5 zipcodes:\n',top_5.head())

#Create individualized time series for each zipcode.
#List containing the 5 different time series.
df_ts = []
for zipcode in top_5.Zipcode.unique():
    # Create separate dataframes for each zipcode with a monthly frequency.
    df_zip = top_5[top_5['Zipcode']==zipcode].asfreq('MS')
    df_ts.append(df_zip)
print('\nZipcode 48894 time series:')
df_ts[0].head()
# Out:
# Time series data for the 5 zipcodes:
#             Zipcode      City State          Metro    CountyName     Price
# Date
# 2005-01-01   85008   Phoenix    AZ        Phoenix      Maricopa  147400.0
# 2005-01-01   94590   Vallejo    CA        Vallejo        Solano  368800.0
# 2005-01-01   94601   Oakland    CA  San Francisco       Alameda  398200.0
# 2005-01-01   94804  Richmond    CA  San Francisco  Contra Costa  445300.0
# 2005-02-01   85008   Phoenix    AZ        Phoenix      Maricopa  150700.0
#
# Zipcode 48894 time series:
#            Zipcode     City State    Metro CountyName     Price
# Date
# 2005-01-01   85008  Phoenix    AZ  Phoenix   Maricopa  147400.0
# 2005-02-01   85008  Phoenix    AZ  Phoenix   Maricopa  150700.0
# 2005-03-01   85008  Phoenix    AZ  Phoenix   Maricopa  154100.0
# 2005-04-01   85008  Phoenix    AZ  Phoenix   Maricopa  157900.0
# 2005-05-01   85008  Phoenix    AZ  Phoenix   Maricopa  161900.0

# %%
 #plotting home prices by zipcodes
for i in range(5):
    df_ts[i].Price.plot(label=df_ts[i].Zipcode[0],figsize=(15,8))
    plt.legend()
plt.title("Home Prices by Zipcode",fontsize=20);

# %% [markdown]
# It can be  noted, there was a price dip attributed to the 2008 market crash, followed by a subsequent price increase that continued from 2012 through 2018."

# %% [markdown]
# We will then create a new column called 'returns' which represent monthly returns on investment

# %%
# creating a column called "returns" representing monthly returns on investment
for zc in range(len(df_ts)):
    df_ts[zc]['returns']=np.nan*len(df_ts[zc])
    for i in range(len(df_ts[zc])-1):
        df_ts[zc]['returns'][i+1]= (df_ts[zc].Price.iloc[i+1] / df_ts[zc].Price.iloc[i]) - 1
        
#Plot the monthly returns of each zipcode
for i in range(len(df_ts)):
    df_ts[i].ret.plot(figsize=(15,10),label=f"Zipcode: {df_ts[i].Zipcode[0]}")
    plt.title(f'Monthly Returns per Zipcode',fontsize=20)
    plt.xlabel('Date',fontsize=15)
    plt.ylabel('Returns (%)',fontsize=15)
    plt.legend(loc='best')
# Out:
# C:\Users\PC\AppData\Local\Temp\ipykernel_5720\4048838521.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ts[zc]['ret'][i+1]= (df_ts[zc].Price.iloc[i+1] / df_ts[zc].Price.iloc[i]) - 1
# C:\Users\PC\AppData\Local\Temp\ipykernel_5720\4048838521.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ts[zc]['ret'][i+1]= (df_ts[zc].Price.iloc[i+1] / df_ts[zc].Price.iloc[i]) - 1
# C:\Users\PC\AppData\Local\Temp\ipykernel_5720\4048838521.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ts[zc]['ret'][i+1]= (df_ts[zc].Price.iloc[i+1] / df_ts[zc].Price.iloc[i]) - 1
# C:\Users\PC\AppData\Local\Temp\ipykernel_5720\4048838521.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ts[zc]['ret'][i+1]= (df_ts[zc].Price.iloc[i+1] / df_ts[zc].Price.iloc[i]) - 1
# C:\Users\PC\AppData\Local\Temp\ipykernel_5720\4048838521.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ts[zc]['ret'][i+1]= (df_ts[zc].Price.iloc[i+1] / df_ts[zc].Price.iloc[i]) - 1
# C:\Users\PC\AppData\Local\Temp\ipykernel_5720\4048838521.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ts[zc]['ret'][i+1]= (df_ts[zc].Price.iloc[i+1] / df_ts[zc].Price.iloc[i]) - 1
# C:\Users\PC\AppData\Local\Temp\ipykernel_5720\4048838521.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ts[zc]['ret'][i+1]= (df_ts[zc].Price.iloc[i+1] / df_ts[zc].Price.iloc[i]) - 1
# C:\Users\PC\AppData\Local\Temp\ipykernel_5720\4048838521.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ts[zc]['ret'][i+1]= (df_ts[zc].Price.iloc[i+1] / df_ts[zc].Price.iloc[i]) - 1
# C:\Users\PC\AppData\Local\Temp\ipykernel_5720\4048838521.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ts[zc]['ret'][i+1]= (df_ts[zc].Price.iloc[i+1] / df_ts[zc].Price.iloc[i]) - 1
# C:\Users\PC\AppData\Local\Temp\ipykernel_5720\4048838521.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ts[zc]['ret'][i+1]= (df_ts[zc].Price.iloc[i+1] / df_ts[zc].Price.iloc[i]) - 1
# C:\Users\PC\AppData\Local\Temp\ipykernel_5720\4048838521.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ts[zc]['ret'][i+1]= (df_ts[zc].Price.iloc[i+1] / df_ts[zc].Price.iloc[i]) - 1
# C:\Users\PC\AppData\Local\Temp\ipykernel_5720\4048838521.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ts[zc]['ret'][i+1]= (df_ts[zc].Price.iloc[i+1] / df_ts[zc].Price.iloc[i]) - 1
# C:\Users\PC\AppData\Local\Temp\ipykernel_5720\4048838521.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ts[zc]['ret'][i+1]= (df_ts[zc].Price.iloc[i+1] / df_ts[zc].Price.iloc[i]) - 1
# C:\Users\PC\AppData\Local\Temp\ipykernel_5720\4048838521.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ts[zc]['ret'][i+1]= (df_ts[zc].Price.iloc[i+1] / df_ts[zc].Price.iloc[i]) - 1
# C:\Users\PC\AppData\Local\Temp\ipykernel_5720\4048838521.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ts[zc]['ret'][i+1]= (df_ts[zc].Price.iloc[i+1] / df_ts[zc].Price.iloc[i]) - 1
# C:\Users\PC\AppData\Local\Temp\ipykernel_5720\4048838521.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ts[zc]['ret'][i+1]= (df_ts[zc].Price.iloc[i+1] / df_ts[zc].Price.iloc[i]) - 1
# C:\Users\PC\AppData\Local\Temp\ipykernel_5720\4048838521.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ts[zc]['ret'][i+1]= (df_ts[zc].Price.iloc[i+1] / df_ts[zc].Price.iloc[i]) - 1
# C:\Users\PC\AppData\Local\Temp\ipykernel_5720\4048838521.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ts[zc]['ret'][i+1]= (df_ts[zc].Price.iloc[i+1] / df_ts[zc].Price.iloc[i]) - 1
# C:\Users\PC\AppData\Local\Temp\ipykernel_5720\4048838521.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ts[zc]['ret'][i+1]= (df_ts[zc].Price.iloc[i+1] / df_ts[zc].Price.iloc[i]) - 1
# C:\Users\PC\AppData\Local\Temp\ipykernel_5720\4048838521.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ts[zc]['ret'][i+1]= (df_ts[zc].Price.iloc[i+1] / df_ts[zc].Price.iloc[i]) - 1
# C:\Users\PC\AppData\Local\Temp\ipykernel_5720\4048838521.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ts[zc]['ret'][i+1]= (df_ts[zc].Price.iloc[i+1] / df_ts[zc].Price.iloc[i]) - 1
# C:\Users\PC\AppData\Local\Temp\ipykernel_5720\4048838521.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ts[zc]['ret'][i+1]= (df_ts[zc].Price.iloc[i+1] / df_ts[zc].Price.iloc[i]) - 1
# C:\Users\PC\AppData\Local\Temp\ipykernel_5720\4048838521.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ts[zc]['ret'][i+1]= (df_ts[zc].Price.iloc[i+1] / df_ts[zc].Price.iloc[i]) - 1
# C:\Users\PC\AppData\Local\Temp\ipykernel_5720\4048838521.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ts[zc]['ret'][i+1]= (df_ts[zc].Price.iloc[i+1] / df_ts[zc].Price.iloc[i]) - 1
# C:\Users\PC\AppData\Local\Temp\ipykernel_5720\4048838521.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ts[zc]['ret'][i+1]= (df_ts[zc].Price.iloc[i+1] / df_ts[zc].Price.iloc[i]) - 1
# C:\Users\PC\AppData\Local\Temp\ipykernel_5720\4048838521.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ts[zc]['ret'][i+1]= (df_ts[zc].Price.iloc[i+1] / df_ts[zc].Price.iloc[i]) - 1
# C:\Users\PC\AppData\Local\Temp\ipykernel_5720\4048838521.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ts[zc]['ret'][i+1]= (df_ts[zc].Price.iloc[i+1] / df_ts[zc].Price.iloc[i]) - 1
# C:\Users\PC\AppData\Local\Temp\ipykernel_5720\4048838521.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ts[zc]['ret'][i+1]= (df_ts[zc].Price.iloc[i+1] / df_ts[zc].Price.iloc[i]) - 1
# C:\Users\PC\AppData\Local\Temp\ipykernel_5720\4048838521.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ts[zc]['ret'][i+1]= (df_ts[zc].Price.iloc[i+1] / df_ts[zc].Price.iloc[i]) - 1
# C:\Users\PC\AppData\Local\Temp\ipykernel_5720\4048838521.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ts[zc]['ret'][i+1]= (df_ts[zc].Price.iloc[i+1] / df_ts[zc].Price.iloc[i]) - 1
# C:\Users\PC\AppData\Local\Temp\ipykernel_5720\4048838521.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ts[zc]['ret'][i+1]= (df_ts[zc].Price.iloc[i+1] / df_ts[zc].Price.iloc[i]) - 1
# C:\Users\PC\AppData\Local\Temp\ipykernel_5720\4048838521.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ts[zc]['ret'][i+1]= (df_ts[zc].Price.iloc[i+1] / df_ts[zc].Price.iloc[i]) - 1
# C:\Users\PC\AppData\Local\Temp\ipykernel_5720\4048838521.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ts[zc]['ret'][i+1]= (df_ts[zc].Price.iloc[i+1] / df_ts[zc].Price.iloc[i]) - 1
# C:\Users\PC\AppData\Local\Temp\ipykernel_5720\4048838521.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ts[zc]['ret'][i+1]= (df_ts[zc].Price.iloc[i+1] / df_ts[zc].Price.iloc[i]) - 1
# C:\Users\PC\AppData\Local\Temp\ipykernel_5720\4048838521.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ts[zc]['ret'][i+1]= (df_ts[zc].Price.iloc[i+1] / df_ts[zc].Price.iloc[i]) - 1
# C:\Users\PC\AppData\Local\Temp\ipykernel_5720\4048838521.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ts[zc]['ret'][i+1]= (df_ts[zc].Price.iloc[i+1] / df_ts[zc].Price.iloc[i]) - 1
# C:\Users\PC\AppData\Local\Temp\ipykernel_5720\4048838521.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ts[zc]['ret'][i+1]= (df_ts[zc].Price.iloc[i+1] / df_ts[zc].Price.iloc[i]) - 1
# C:\Users\PC\AppData\Local\Temp\ipykernel_5720\4048838521.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ts[zc]['ret'][i+1]= (df_ts[zc].Price.iloc[i+1] / df_ts[zc].Price.iloc[i]) - 1
# C:\Users\PC\AppData\Local\Temp\ipykernel_5720\4048838521.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ts[zc]['ret'][i+1]= (df_ts[zc].Price.iloc[i+1] / df_ts[zc].Price.iloc[i]) - 1
# C:\Users\PC\AppData\Local\Temp\ipykernel_5720\4048838521.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ts[zc]['ret'][i+1]= (df_ts[zc].Price.iloc[i+1] / df_ts[zc].Price.iloc[i]) - 1
# C:\Users\PC\AppData\Local\Temp\ipykernel_5720\4048838521.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ts[zc]['ret'][i+1]= (df_ts[zc].Price.iloc[i+1] / df_ts[zc].Price.iloc[i]) - 1
# C:\Users\PC\AppData\Local\Temp\ipykernel_5720\4048838521.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ts[zc]['ret'][i+1]= (df_ts[zc].Price.iloc[i+1] / df_ts[zc].Price.iloc[i]) - 1
# C:\Users\PC\AppData\Local\Temp\ipykernel_5720\4048838521.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ts[zc]['ret'][i+1]= (df_ts[zc].Price.iloc[i+1] / df_ts[zc].Price.iloc[i]) - 1
# C:\Users\PC\AppData\Local\Temp\ipykernel_5720\4048838521.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ts[zc]['ret'][i+1]= (df_ts[zc].Price.iloc[i+1] / df_ts[zc].Price.iloc[i]) - 1
# C:\Users\PC\AppData\Local\Temp\ipykernel_5720\4048838521.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ts[zc]['ret'][i+1]= (df_ts[zc].Price.iloc[i+1] / df_ts[zc].Price.iloc[i]) - 1
# C:\Users\PC\AppData\Local\Temp\ipykernel_5720\4048838521.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ts[zc]['ret'][i+1]= (df_ts[zc].Price.iloc[i+1] / df_ts[zc].Price.iloc[i]) - 1
# C:\Users\PC\AppData\Local\Temp\ipykernel_5720\4048838521.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ts[zc]['ret'][i+1]= (df_ts[zc].Price.iloc[i+1] / df_ts[zc].Price.iloc[i]) - 1
# C:\Users\PC\AppData\Local\Temp\ipykernel_5720\4048838521.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ts[zc]['ret'][i+1]= (df_ts[zc].Price.iloc[i+1] / df_ts[zc].Price.iloc[i]) - 1
# C:\Users\PC\AppData\Local\Temp\ipykernel_5720\4048838521.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ts[zc]['ret'][i+1]= (df_ts[zc].Price.iloc[i+1] / df_ts[zc].Price.iloc[i]) - 1
# C:\Users\PC\AppData\Local\Temp\ipykernel_5720\4048838521.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ts[zc]['ret'][i+1]= (df_ts[zc].Price.iloc[i+1] / df_ts[zc].Price.iloc[i]) - 1
# C:\Users\PC\AppData\Local\Temp\ipykernel_5720\4048838521.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ts[zc]['ret'][i+1]= (df_ts[zc].Price.iloc[i+1] / df_ts[zc].Price.iloc[i]) - 1
# C:\Users\PC\AppData\Local\Temp\ipykernel_5720\4048838521.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ts[zc]['ret'][i+1]= (df_ts[zc].Price.iloc[i+1] / df_ts[zc].Price.iloc[i]) - 1
# C:\Users\PC\AppData\Local\Temp\ipykernel_5720\4048838521.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ts[zc]['ret'][i+1]= (df_ts[zc].Price.iloc[i+1] / df_ts[zc].Price.iloc[i]) - 1
# C:\Users\PC\AppData\Local\Temp\ipykernel_5720\4048838521.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ts[zc]['ret'][i+1]= (df_ts[zc].Price.iloc[i+1] / df_ts[zc].Price.iloc[i]) - 1
# C:\Users\PC\AppData\Local\Temp\ipykernel_5720\4048838521.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ts[zc]['ret'][i+1]= (df_ts[zc].Price.iloc[i+1] / df_ts[zc].Price.iloc[i]) - 1
# C:\Users\PC\AppData\Local\Temp\ipykernel_5720\4048838521.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ts[zc]['ret'][i+1]= (df_ts[zc].Price.iloc[i+1] / df_ts[zc].Price.iloc[i]) - 1
# C:\Users\PC\AppData\Local\Temp\ipykernel_5720\4048838521.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ts[zc]['ret'][i+1]= (df_ts[zc].Price.iloc[i+1] / df_ts[zc].Price.iloc[i]) - 1
# C:\Users\PC\AppData\Local\Temp\ipykernel_5720\4048838521.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ts[zc]['ret'][i+1]= (df_ts[zc].Price.iloc[i+1] / df_ts[zc].Price.iloc[i]) - 1
# C:\Users\PC\AppData\Local\Temp\ipykernel_5720\4048838521.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ts[zc]['ret'][i+1]= (df_ts[zc].Price.iloc[i+1] / df_ts[zc].Price.iloc[i]) - 1
# C:\Users\PC\AppData\Local\Temp\ipykernel_5720\4048838521.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ts[zc]['ret'][i+1]= (df_ts[zc].Price.iloc[i+1] / df_ts[zc].Price.iloc[i]) - 1
# C:\Users\PC\AppData\Local\Temp\ipykernel_5720\4048838521.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ts[zc]['ret'][i+1]= (df_ts[zc].Price.iloc[i+1] / df_ts[zc].Price.iloc[i]) - 1
# C:\Users\PC\AppData\Local\Temp\ipykernel_5720\4048838521.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ts[zc]['ret'][i+1]= (df_ts[zc].Price.iloc[i+1] / df_ts[zc].Price.iloc[i]) - 1
# C:\Users\PC\AppData\Local\Temp\ipykernel_5720\4048838521.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ts[zc]['ret'][i+1]= (df_ts[zc].Price.iloc[i+1] / df_ts[zc].Price.iloc[i]) - 1
# C:\Users\PC\AppData\Local\Temp\ipykernel_5720\4048838521.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ts[zc]['ret'][i+1]= (df_ts[zc].Price.iloc[i+1] / df_ts[zc].Price.iloc[i]) - 1
# C:\Users\PC\AppData\Local\Temp\ipykernel_5720\4048838521.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ts[zc]['ret'][i+1]= (df_ts[zc].Price.iloc[i+1] / df_ts[zc].Price.iloc[i]) - 1
# C:\Users\PC\AppData\Local\Temp\ipykernel_5720\4048838521.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ts[zc]['ret'][i+1]= (df_ts[zc].Price.iloc[i+1] / df_ts[zc].Price.iloc[i]) - 1
# C:\Users\PC\AppData\Local\Temp\ipykernel_5720\4048838521.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ts[zc]['ret'][i+1]= (df_ts[zc].Price.iloc[i+1] / df_ts[zc].Price.iloc[i]) - 1
# C:\Users\PC\AppData\Local\Temp\ipykernel_5720\4048838521.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ts[zc]['ret'][i+1]= (df_ts[zc].Price.iloc[i+1] / df_ts[zc].Price.iloc[i]) - 1
# C:\Users\PC\AppData\Local\Temp\ipykernel_5720\4048838521.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ts[zc]['ret'][i+1]= (df_ts[zc].Price.iloc[i+1] / df_ts[zc].Price.iloc[i]) - 1
# C:\Users\PC\AppData\Local\Temp\ipykernel_5720\4048838521.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ts[zc]['ret'][i+1]= (df_ts[zc].Price.iloc[i+1] / df_ts[zc].Price.iloc[i]) - 1
# C:\Users\PC\AppData\Local\Temp\ipykernel_5720\4048838521.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ts[zc]['ret'][i+1]= (df_ts[zc].Price.iloc[i+1] / df_ts[zc].Price.iloc[i]) - 1
# C:\Users\PC\AppData\Local\Temp\ipykernel_5720\4048838521.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ts[zc]['ret'][i+1]= (df_ts[zc].Price.iloc[i+1] / df_ts[zc].Price.iloc[i]) - 1
# C:\Users\PC\AppData\Local\Temp\ipykernel_5720\4048838521.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ts[zc]['ret'][i+1]= (df_ts[zc].Price.iloc[i+1] / df_ts[zc].Price.iloc[i]) - 1
# C:\Users\PC\AppData\Local\Temp\ipykernel_5720\4048838521.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ts[zc]['ret'][i+1]= (df_ts[zc].Price.iloc[i+1] / df_ts[zc].Price.iloc[i]) - 1
# C:\Users\PC\AppData\Local\Temp\ipykernel_5720\4048838521.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ts[zc]['ret'][i+1]= (df_ts[zc].Price.iloc[i+1] / df_ts[zc].Price.iloc[i]) - 1
# C:\Users\PC\AppData\Local\Temp\ipykernel_5720\4048838521.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ts[zc]['ret'][i+1]= (df_ts[zc].Price.iloc[i+1] / df_ts[zc].Price.iloc[i]) - 1
# C:\Users\PC\AppData\Local\Temp\ipykernel_5720\4048838521.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ts[zc]['ret'][i+1]= (df_ts[zc].Price.iloc[i+1] / df_ts[zc].Price.iloc[i]) - 1
# C:\Users\PC\AppData\Local\Temp\ipykernel_5720\4048838521.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ts[zc]['ret'][i+1]= (df_ts[zc].Price.iloc[i+1] / df_ts[zc].Price.iloc[i]) - 1
# C:\Users\PC\AppData\Local\Temp\ipykernel_5720\4048838521.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ts[zc]['ret'][i+1]= (df_ts[zc].Price.iloc[i+1] / df_ts[zc].Price.iloc[i]) - 1
# C:\Users\PC\AppData\Local\Temp\ipykernel_5720\4048838521.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ts[zc]['ret'][i+1]= (df_ts[zc].Price.iloc[i+1] / df_ts[zc].Price.iloc[i]) - 1
# C:\Users\PC\AppData\Local\Temp\ipykernel_5720\4048838521.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ts[zc]['ret'][i+1]= (df_ts[zc].Price.iloc[i+1] / df_ts[zc].Price.iloc[i]) - 1
# C:\Users\PC\AppData\Local\Temp\ipykernel_5720\4048838521.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ts[zc]['ret'][i+1]= (df_ts[zc].Price.iloc[i+1] / df_ts[zc].Price.iloc[i]) - 1
# C:\Users\PC\AppData\Local\Temp\ipykernel_5720\4048838521.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ts[zc]['ret'][i+1]= (df_ts[zc].Price.iloc[i+1] / df_ts[zc].Price.iloc[i]) - 1
# C:\Users\PC\AppData\Local\Temp\ipykernel_5720\4048838521.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ts[zc]['ret'][i+1]= (df_ts[zc].Price.iloc[i+1] / df_ts[zc].Price.iloc[i]) - 1
# C:\Users\PC\AppData\Local\Temp\ipykernel_5720\4048838521.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ts[zc]['ret'][i+1]= (df_ts[zc].Price.iloc[i+1] / df_ts[zc].Price.iloc[i]) - 1
# C:\Users\PC\AppData\Local\Temp\ipykernel_5720\4048838521.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ts[zc]['ret'][i+1]= (df_ts[zc].Price.iloc[i+1] / df_ts[zc].Price.iloc[i]) - 1
# C:\Users\PC\AppData\Local\Temp\ipykernel_5720\4048838521.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ts[zc]['ret'][i+1]= (df_ts[zc].Price.iloc[i+1] / df_ts[zc].Price.iloc[i]) - 1
# C:\Users\PC\AppData\Local\Temp\ipykernel_5720\4048838521.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ts[zc]['ret'][i+1]= (df_ts[zc].Price.iloc[i+1] / df_ts[zc].Price.iloc[i]) - 1
# C:\Users\PC\AppData\Local\Temp\ipykernel_5720\4048838521.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ts[zc]['ret'][i+1]= (df_ts[zc].Price.iloc[i+1] / df_ts[zc].Price.iloc[i]) - 1
# C:\Users\PC\AppData\Local\Temp\ipykernel_5720\4048838521.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ts[zc]['ret'][i+1]= (df_ts[zc].Price.iloc[i+1] / df_ts[zc].Price.iloc[i]) - 1
# C:\Users\PC\AppData\Local\Temp\ipykernel_5720\4048838521.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ts[zc]['ret'][i+1]= (df_ts[zc].Price.iloc[i+1] / df_ts[zc].Price.iloc[i]) - 1
# C:\Users\PC\AppData\Local\Temp\ipykernel_5720\4048838521.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ts[zc]['ret'][i+1]= (df_ts[zc].Price.iloc[i+1] / df_ts[zc].Price.iloc[i]) - 1
# C:\Users\PC\AppData\Local\Temp\ipykernel_5720\4048838521.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ts[zc]['ret'][i+1]= (df_ts[zc].Price.iloc[i+1] / df_ts[zc].Price.iloc[i]) - 1
# C:\Users\PC\AppData\Local\Temp\ipykernel_5720\4048838521.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ts[zc]['ret'][i+1]= (df_ts[zc].Price.iloc[i+1] / df_ts[zc].Price.iloc[i]) - 1
# C:\Users\PC\AppData\Local\Temp\ipykernel_5720\4048838521.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ts[zc]['ret'][i+1]= (df_ts[zc].Price.iloc[i+1] / df_ts[zc].Price.iloc[i]) - 1
# C:\Users\PC\AppData\Local\Temp\ipykernel_5720\4048838521.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ts[zc]['ret'][i+1]= (df_ts[zc].Price.iloc[i+1] / df_ts[zc].Price.iloc[i]) - 1
# C:\Users\PC\AppData\Local\Temp\ipykernel_5720\4048838521.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ts[zc]['ret'][i+1]= (df_ts[zc].Price.iloc[i+1] / df_ts[zc].Price.iloc[i]) - 1
# C:\Users\PC\AppData\Local\Temp\ipykernel_5720\4048838521.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ts[zc]['ret'][i+1]= (df_ts[zc].Price.iloc[i+1] / df_ts[zc].Price.iloc[i]) - 1
# C:\Users\PC\AppData\Local\Temp\ipykernel_5720\4048838521.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ts[zc]['ret'][i+1]= (df_ts[zc].Price.iloc[i+1] / df_ts[zc].Price.iloc[i]) - 1
# C:\Users\PC\AppData\Local\Temp\ipykernel_5720\4048838521.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ts[zc]['ret'][i+1]= (df_ts[zc].Price.iloc[i+1] / df_ts[zc].Price.iloc[i]) - 1
# C:\Users\PC\AppData\Local\Temp\ipykernel_5720\4048838521.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ts[zc]['ret'][i+1]= (df_ts[zc].Price.iloc[i+1] / df_ts[zc].Price.iloc[i]) - 1
# C:\Users\PC\AppData\Local\Temp\ipykernel_5720\4048838521.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ts[zc]['ret'][i+1]= (df_ts[zc].Price.iloc[i+1] / df_ts[zc].Price.iloc[i]) - 1
# C:\Users\PC\AppData\Local\Temp\ipykernel_5720\4048838521.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ts[zc]['ret'][i+1]= (df_ts[zc].Price.iloc[i+1] / df_ts[zc].Price.iloc[i]) - 1
# C:\Users\PC\AppData\Local\Temp\ipykernel_5720\4048838521.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ts[zc]['ret'][i+1]= (df_ts[zc].Price.iloc[i+1] / df_ts[zc].Price.iloc[i]) - 1
# C:\Users\PC\AppData\Local\Temp\ipykernel_5720\4048838521.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ts[zc]['ret'][i+1]= (df_ts[zc].Price.iloc[i+1] / df_ts[zc].Price.iloc[i]) - 1
# C:\Users\PC\AppData\Local\Temp\ipykernel_5720\4048838521.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ts[zc]['ret'][i+1]= (df_ts[zc].Price.iloc[i+1] / df_ts[zc].Price.iloc[i]) - 1
# C:\Users\PC\AppData\Local\Temp\ipykernel_5720\4048838521.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ts[zc]['ret'][i+1]= (df_ts[zc].Price.iloc[i+1] / df_ts[zc].Price.iloc[i]) - 1
# C:\Users\PC\AppData\Local\Temp\ipykernel_5720\4048838521.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ts[zc]['ret'][i+1]= (df_ts[zc].Price.iloc[i+1] / df_ts[zc].Price.iloc[i]) - 1
# C:\Users\PC\AppData\Local\Temp\ipykernel_5720\4048838521.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ts[zc]['ret'][i+1]= (df_ts[zc].Price.iloc[i+1] / df_ts[zc].Price.iloc[i]) - 1
# C:\Users\PC\AppData\Local\Temp\ipykernel_5720\4048838521.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ts[zc]['ret'][i+1]= (df_ts[zc].Price.iloc[i+1] / df_ts[zc].Price.iloc[i]) - 1
# C:\Users\PC\AppData\Local\Temp\ipykernel_5720\4048838521.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ts[zc]['ret'][i+1]= (df_ts[zc].Price.iloc[i+1] / df_ts[zc].Price.iloc[i]) - 1
# C:\Users\PC\AppData\Local\Temp\ipykernel_5720\4048838521.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ts[zc]['ret'][i+1]= (df_ts[zc].Price.iloc[i+1] / df_ts[zc].Price.iloc[i]) - 1
# C:\Users\PC\AppData\Local\Temp\ipykernel_5720\4048838521.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ts[zc]['ret'][i+1]= (df_ts[zc].Price.iloc[i+1] / df_ts[zc].Price.iloc[i]) - 1
# C:\Users\PC\AppData\Local\Temp\ipykernel_5720\4048838521.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ts[zc]['ret'][i+1]= (df_ts[zc].Price.iloc[i+1] / df_ts[zc].Price.iloc[i]) - 1
# C:\Users\PC\AppData\Local\Temp\ipykernel_5720\4048838521.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ts[zc]['ret'][i+1]= (df_ts[zc].Price.iloc[i+1] / df_ts[zc].Price.iloc[i]) - 1
# C:\Users\PC\AppData\Local\Temp\ipykernel_5720\4048838521.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ts[zc]['ret'][i+1]= (df_ts[zc].Price.iloc[i+1] / df_ts[zc].Price.iloc[i]) - 1
# C:\Users\PC\AppData\Local\Temp\ipykernel_5720\4048838521.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ts[zc]['ret'][i+1]= (df_ts[zc].Price.iloc[i+1] / df_ts[zc].Price.iloc[i]) - 1
# C:\Users\PC\AppData\Local\Temp\ipykernel_5720\4048838521.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ts[zc]['ret'][i+1]= (df_ts[zc].Price.iloc[i+1] / df_ts[zc].Price.iloc[i]) - 1
# C:\Users\PC\AppData\Local\Temp\ipykernel_5720\4048838521.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ts[zc]['ret'][i+1]= (df_ts[zc].Price.iloc[i+1] / df_ts[zc].Price.iloc[i]) - 1
# C:\Users\PC\AppData\Local\Temp\ipykernel_5720\4048838521.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ts[zc]['ret'][i+1]= (df_ts[zc].Price.iloc[i+1] / df_ts[zc].Price.iloc[i]) - 1
# C:\Users\PC\AppData\Local\Temp\ipykernel_5720\4048838521.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ts[zc]['ret'][i+1]= (df_ts[zc].Price.iloc[i+1] / df_ts[zc].Price.iloc[i]) - 1
# C:\Users\PC\AppData\Local\Temp\ipykernel_5720\4048838521.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ts[zc]['ret'][i+1]= (df_ts[zc].Price.iloc[i+1] / df_ts[zc].Price.iloc[i]) - 1
# C:\Users\PC\AppData\Local\Temp\ipykernel_5720\4048838521.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ts[zc]['ret'][i+1]= (df_ts[zc].Price.iloc[i+1] / df_ts[zc].Price.iloc[i]) - 1
# C:\Users\PC\AppData\Local\Temp\ipykernel_5720\4048838521.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ts[zc]['ret'][i+1]= (df_ts[zc].Price.iloc[i+1] / df_ts[zc].Price.iloc[i]) - 1
# C:\Users\PC\AppData\Local\Temp\ipykernel_5720\4048838521.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ts[zc]['ret'][i+1]= (df_ts[zc].Price.iloc[i+1] / df_ts[zc].Price.iloc[i]) - 1
# C:\Users\PC\AppData\Local\Temp\ipykernel_5720\4048838521.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ts[zc]['ret'][i+1]= (df_ts[zc].Price.iloc[i+1] / df_ts[zc].Price.iloc[i]) - 1
# C:\Users\PC\AppData\Local\Temp\ipykernel_5720\4048838521.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ts[zc]['ret'][i+1]= (df_ts[zc].Price.iloc[i+1] / df_ts[zc].Price.iloc[i]) - 1
# C:\Users\PC\AppData\Local\Temp\ipykernel_5720\4048838521.py:5: SettingWithCopyWarning:
# ...
#   df_ts[zc]['ret'][i+1]= (df_ts[zc].Price.iloc[i+1] / df_ts[zc].Price.iloc[i]) - 1
# C:\Users\PC\AppData\Local\Temp\ipykernel_5720\4048838521.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ts[zc]['ret'][i+1]= (df_ts[zc].Price.iloc[i+1] / df_ts[zc].Price.iloc[i]) - 1
# C:\Users\PC\AppData\Local\Temp\ipykernel_5720\4048838521.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ts[zc]['ret'][i+1]= (df_ts[zc].Price.iloc[i+1] / df_ts[zc].Price.iloc[i]) - 1
# C:\Users\PC\AppData\Local\Temp\ipykernel_5720\4048838521.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ts[zc]['ret'][i+1]= (df_ts[zc].Price.iloc[i+1] / df_ts[zc].Price.iloc[i]) - 1
# C:\Users\PC\AppData\Local\Temp\ipykernel_5720\4048838521.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ts[zc]['ret'][i+1]= (df_ts[zc].Price.iloc[i+1] / df_ts[zc].Price.iloc[i]) - 1
# C:\Users\PC\AppData\Local\Temp\ipykernel_5720\4048838521.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ts[zc]['ret'][i+1]= (df_ts[zc].Price.iloc[i+1] / df_ts[zc].Price.iloc[i]) - 1
# C:\Users\PC\AppData\Local\Temp\ipykernel_5720\4048838521.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ts[zc]['ret'][i+1]= (df_ts[zc].Price.iloc[i+1] / df_ts[zc].Price.iloc[i]) - 1
# C:\Users\PC\AppData\Local\Temp\ipykernel_5720\4048838521.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ts[zc]['ret'][i+1]= (df_ts[zc].Price.iloc[i+1] / df_ts[zc].Price.iloc[i]) - 1
# C:\Users\PC\AppData\Local\Temp\ipykernel_5720\4048838521.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ts[zc]['ret'][i+1]= (df_ts[zc].Price.iloc[i+1] / df_ts[zc].Price.iloc[i]) - 1
# C:\Users\PC\AppData\Local\Temp\ipykernel_5720\4048838521.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ts[zc]['ret'][i+1]= (df_ts[zc].Price.iloc[i+1] / df_ts[zc].Price.iloc[i]) - 1
# C:\Users\PC\AppData\Local\Temp\ipykernel_5720\4048838521.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ts[zc]['ret'][i+1]= (df_ts[zc].Price.iloc[i+1] / df_ts[zc].Price.iloc[i]) - 1
# C:\Users\PC\AppData\Local\Temp\ipykernel_5720\4048838521.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ts[zc]['ret'][i+1]= (df_ts[zc].Price.iloc[i+1] / df_ts[zc].Price.iloc[i]) - 1
# C:\Users\PC\AppData\Local\Temp\ipykernel_5720\4048838521.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ts[zc]['ret'][i+1]= (df_ts[zc].Price.iloc[i+1] / df_ts[zc].Price.iloc[i]) - 1
# C:\Users\PC\AppData\Local\Temp\ipykernel_5720\4048838521.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ts[zc]['ret'][i+1]= (df_ts[zc].Price.iloc[i+1] / df_ts[zc].Price.iloc[i]) - 1
# C:\Users\PC\AppData\Local\Temp\ipykernel_5720\4048838521.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ts[zc]['ret'][i+1]= (df_ts[zc].Price.iloc[i+1] / df_ts[zc].Price.iloc[i]) - 1
# C:\Users\PC\AppData\Local\Temp\ipykernel_5720\4048838521.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ts[zc]['ret'][i+1]= (df_ts[zc].Price.iloc[i+1] / df_ts[zc].Price.iloc[i]) - 1
# C:\Users\PC\AppData\Local\Temp\ipykernel_5720\4048838521.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ts[zc]['ret'][i+1]= (df_ts[zc].Price.iloc[i+1] / df_ts[zc].Price.iloc[i]) - 1
# C:\Users\PC\AppData\Local\Temp\ipykernel_5720\4048838521.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ts[zc]['ret'][i+1]= (df_ts[zc].Price.iloc[i+1] / df_ts[zc].Price.iloc[i]) - 1
# C:\Users\PC\AppData\Local\Temp\ipykernel_5720\4048838521.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ts[zc]['ret'][i+1]= (df_ts[zc].Price.iloc[i+1] / df_ts[zc].Price.iloc[i]) - 1
# C:\Users\PC\AppData\Local\Temp\ipykernel_5720\4048838521.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ts[zc]['ret'][i+1]= (df_ts[zc].Price.iloc[i+1] / df_ts[zc].Price.iloc[i]) - 1
# C:\Users\PC\AppData\Local\Temp\ipykernel_5720\4048838521.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ts[zc]['ret'][i+1]= (df_ts[zc].Price.iloc[i+1] / df_ts[zc].Price.iloc[i]) - 1
# C:\Users\PC\AppData\Local\Temp\ipykernel_5720\4048838521.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ts[zc]['ret'][i+1]= (df_ts[zc].Price.iloc[i+1] / df_ts[zc].Price.iloc[i]) - 1
# C:\Users\PC\AppData\Local\Temp\ipykernel_5720\4048838521.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ts[zc]['ret'][i+1]= (df_ts[zc].Price.iloc[i+1] / df_ts[zc].Price.iloc[i]) - 1
# C:\Users\PC\AppData\Local\Temp\ipykernel_5720\4048838521.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ts[zc]['ret'][i+1]= (df_ts[zc].Price.iloc[i+1] / df_ts[zc].Price.iloc[i]) - 1
# C:\Users\PC\AppData\Local\Temp\ipykernel_5720\4048838521.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ts[zc]['ret'][i+1]= (df_ts[zc].Price.iloc[i+1] / df_ts[zc].Price.iloc[i]) - 1
# C:\Users\PC\AppData\Local\Temp\ipykernel_5720\4048838521.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ts[zc]['ret'][i+1]= (df_ts[zc].Price.iloc[i+1] / df_ts[zc].Price.iloc[i]) - 1
# C:\Users\PC\AppData\Local\Temp\ipykernel_5720\4048838521.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ts[zc]['ret'][i+1]= (df_ts[zc].Price.iloc[i+1] / df_ts[zc].Price.iloc[i]) - 1
# C:\Users\PC\AppData\Local\Temp\ipykernel_5720\4048838521.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ts[zc]['ret'][i+1]= (df_ts[zc].Price.iloc[i+1] / df_ts[zc].Price.iloc[i]) - 1
# C:\Users\PC\AppData\Local\Temp\ipykernel_5720\4048838521.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ts[zc]['ret'][i+1]= (df_ts[zc].Price.iloc[i+1] / df_ts[zc].Price.iloc[i]) - 1
# C:\Users\PC\AppData\Local\Temp\ipykernel_5720\4048838521.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ts[zc]['ret'][i+1]= (df_ts[zc].Price.iloc[i+1] / df_ts[zc].Price.iloc[i]) - 1
# C:\Users\PC\AppData\Local\Temp\ipykernel_5720\4048838521.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ts[zc]['ret'][i+1]= (df_ts[zc].Price.iloc[i+1] / df_ts[zc].Price.iloc[i]) - 1
# C:\Users\PC\AppData\Local\Temp\ipykernel_5720\4048838521.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ts[zc]['ret'][i+1]= (df_ts[zc].Price.iloc[i+1] / df_ts[zc].Price.iloc[i]) - 1
# C:\Users\PC\AppData\Local\Temp\ipykernel_5720\4048838521.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ts[zc]['ret'][i+1]= (df_ts[zc].Price.iloc[i+1] / df_ts[zc].Price.iloc[i]) - 1
# C:\Users\PC\AppData\Local\Temp\ipykernel_5720\4048838521.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ts[zc]['ret'][i+1]= (df_ts[zc].Price.iloc[i+1] / df_ts[zc].Price.iloc[i]) - 1
# C:\Users\PC\AppData\Local\Temp\ipykernel_5720\4048838521.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ts[zc]['ret'][i+1]= (df_ts[zc].Price.iloc[i+1] / df_ts[zc].Price.iloc[i]) - 1
# C:\Users\PC\AppData\Local\Temp\ipykernel_5720\4048838521.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ts[zc]['ret'][i+1]= (df_ts[zc].Price.iloc[i+1] / df_ts[zc].Price.iloc[i]) - 1
# C:\Users\PC\AppData\Local\Temp\ipykernel_5720\4048838521.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ts[zc]['ret'][i+1]= (df_ts[zc].Price.iloc[i+1] / df_ts[zc].Price.iloc[i]) - 1
# C:\Users\PC\AppData\Local\Temp\ipykernel_5720\4048838521.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ts[zc]['ret'][i+1]= (df_ts[zc].Price.iloc[i+1] / df_ts[zc].Price.iloc[i]) - 1
# C:\Users\PC\AppData\Local\Temp\ipykernel_5720\4048838521.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ts[zc]['ret'][i+1]= (df_ts[zc].Price.iloc[i+1] / df_ts[zc].Price.iloc[i]) - 1
# C:\Users\PC\AppData\Local\Temp\ipykernel_5720\4048838521.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ts[zc]['ret'][i+1]= (df_ts[zc].Price.iloc[i+1] / df_ts[zc].Price.iloc[i]) - 1
# C:\Users\PC\AppData\Local\Temp\ipykernel_5720\4048838521.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ts[zc]['ret'][i+1]= (df_ts[zc].Price.iloc[i+1] / df_ts[zc].Price.iloc[i]) - 1
# C:\Users\PC\AppData\Local\Temp\ipykernel_5720\4048838521.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ts[zc]['ret'][i+1]= (df_ts[zc].Price.iloc[i+1] / df_ts[zc].Price.iloc[i]) - 1
# C:\Users\PC\AppData\Local\Temp\ipykernel_5720\4048838521.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ts[zc]['ret'][i+1]= (df_ts[zc].Price.iloc[i+1] / df_ts[zc].Price.iloc[i]) - 1

# %% [markdown]
# We can observe that there is no stationarity

# %% [markdown]
# **Dickey Fuller test for stationarity**

# %%
# performing Dicky-fuller test for stationarity
for i in range(5):
    results = adfuller(df_ts[i].ret.dropna())
    print(f'ADFuller test p-value for zipcode: {df_ts[i].Zipcode[0]}')
    print('p-value:',results[1])
    
    if results[1]>0.05:
        print('Fail to reject the null hypothesis. Data is not stationary.\n')
    else:
        print('Reject the null hypothesis. Data is stationary.\n')
# Out:
# ADFuller test p-value for zipcode: 85008
# p-value: 0.6295372473847544
# Fail to reject the null hypothesis. Data is not stationary.
#
# ADFuller test p-value for zipcode: 94590
# p-value: 0.3731739915627189
# Fail to reject the null hypothesis. Data is not stationary.
#
# ADFuller test p-value for zipcode: 94601
# p-value: 0.2971634087991125
# Fail to reject the null hypothesis. Data is not stationary.
#
# ADFuller test p-value for zipcode: 94804
# p-value: 0.367365479458574
# Fail to reject the null hypothesis. Data is not stationary.
#
# ADFuller test p-value for zipcode: 85035
# p-value: 0.0191331491842596
# Reject the null hypothesis. Data is stationary.

# %%
# differencing the non stationary zip codes
for i in [0,2,3,4]:
    #Perform adfuller test and drop NaN values created when calculating monthly returns.
    results = adfuller(df_ts[i].ret.diff().dropna())
    print(f'ADFuller test p-value for zipcode: {df_ts[i].Zipcode[0]}')
    print('p-value:',results[1])
    
    if results[1]>0.05:
        print('Fail to reject the null hypothesis. Data is not stationary.\n')
    else:
        print('Reject the null hypothesis. Data is stationary.\n')
# Out:
# ADFuller test p-value for zipcode: 85008
# p-value: 0.00014841526602511266
# Reject the null hypothesis. Data is stationary.
#
# ADFuller test p-value for zipcode: 94601
# p-value: 0.010223197023987165
# Reject the null hypothesis. Data is stationary.
#
# ADFuller test p-value for zipcode: 94804
# p-value: 1.9697301465546046e-07
# Reject the null hypothesis. Data is stationary.
#
# ADFuller test p-value for zipcode: 85035
# p-value: 7.943834444956244e-06
# Reject the null hypothesis. Data is stationary.

# %% [markdown]
# Since our data is now fully stationary we can now perform modeling

# %% [markdown]
# **MODELING**

# %% [markdown]
# Since the goal is to identify the top five zipcodes for investment and create a separate forecasting model for each of these zipcodes. This approach allows investors to make informed decisions by predicting price trends in these specific areas.

# %%
# creating individual time series 
ts_85035 = df_ts[1].ret.dropna()
ts_85008 = df_ts[0].ret.diff().dropna()
ts_94590 = df_ts[2].ret.diff().dropna()
ts_94601 = df_ts[3].ret.diff().dropna()
ts_94804 = df_ts[4].ret.diff().dropna()

# %%
# defining a function that plots acf and pacf plots
def acf_pacf(df,alags=40,plags=40):
    #Create figure
    fig,(ax1,ax2) = plt.subplots(2,1,figsize=(15,8))
    #Make ACF plot
    plot_acf(df,lags=alags, zero=False,ax=ax1)
    #Make PACF plot
    plot_pacf(df,lags=plags, ax=ax2)
    plt.show()

# %%
# plotting acf and pacf for zipcode 85035
acf_pacf(ts_85035)

# %%
# using auto arima to find the best p,d,q for our model
model = pm.auto_arima(ts_85035, trace=True, error_action='ignore', suppress_warnings=True, stepwise=True)
print(model.summary())
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=-1253.511, Time=0.69 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=-1200.370, Time=0.12 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=-1222.069, Time=0.05 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=-1241.997, Time=0.13 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=-1202.367, Time=0.05 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=-1239.736, Time=0.33 sec
#  ARIMA(2,1,1)(0,0,0)[0] intercept   : AIC=-1247.050, Time=0.15 sec
#  ARIMA(3,1,2)(0,0,0)[0] intercept   : AIC=-1242.276, Time=0.18 sec
#  ARIMA(2,1,3)(0,0,0)[0] intercept   : AIC=-1255.857, Time=0.54 sec
#  ARIMA(1,1,3)(0,0,0)[0] intercept   : AIC=-1256.000, Time=0.32 sec
#  ARIMA(0,1,3)(0,0,0)[0] intercept   : AIC=-1255.350, Time=0.10 sec
#  ARIMA(1,1,4)(0,0,0)[0] intercept   : AIC=-1255.609, Time=0.27 sec
#  ARIMA(0,1,2)(0,0,0)[0] intercept   : AIC=-1240.139, Time=0.25 sec
#  ARIMA(0,1,4)(0,0,0)[0] intercept   : AIC=-1257.680, Time=0.76 sec
#  ARIMA(0,1,5)(0,0,0)[0] intercept   : AIC=-1256.461, Time=0.89 sec
#  ARIMA(1,1,5)(0,0,0)[0] intercept   : AIC=-1251.913, Time=0.36 sec
#  ARIMA(0,1,4)(0,0,0)[0]             : AIC=-1259.416, Time=0.45 sec
#  ARIMA(0,1,3)(0,0,0)[0]             : AIC=-1257.345, Time=0.10 sec
#  ARIMA(1,1,4)(0,0,0)[0]             : AIC=-1258.075, Time=0.50 sec
#  ARIMA(0,1,5)(0,0,0)[0]             : AIC=-1257.089, Time=0.19 sec
#  ARIMA(1,1,3)(0,0,0)[0]             : AIC=-1256.866, Time=0.21 sec
#  ARIMA(1,1,5)(0,0,0)[0]             : AIC=-1253.916, Time=0.18 sec
#
# Best model:  ARIMA(0,1,4)(0,0,0)[0]
# Total fit time: 6.863 seconds
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                  159
# Model:               SARIMAX(0, 1, 4)   Log Likelihood                 634.708
# Date:                Fri, 15 Sep 2023   AIC                          -1259.416
# Time:                        12:36:58   BIC                          -1244.103
# Sample:                    02-01-2005   HQIC                         -1253.197
#                          - 04-01-2018
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ma.L1          0.6066      0.062      9.735      0.000       0.484       0.729
# ma.L2         -0.1591      0.068     -2.331      0.020      -0.293      -0.025
# ma.L3         -0.3044      0.052     -5.800      0.000      -0.407      -0.202
# ma.L4          0.1376      0.058      2.372      0.018       0.024       0.251
# sigma2      1.884e-05   1.67e-06     11.291      0.000    1.56e-05    2.21e-05
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.15   Jarque-Bera (JB):                14.40
# Prob(Q):                              0.70   Prob(JB):                         0.00
# Heteroskedasticity (H):               2.03   Skew:                             0.06
# Prob(H) (two-sided):                  0.01   Kurtosis:                         4.47
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
#splitting the data into train and test
train_85035 = ts_85035[:'2015-01']
test_85035 = ts_85035['2015-02':]

# %% [markdown]
# Fitting an ARIMA Model on the training series. The parameters to be used will be gotten from the AUTO ARIMA model above.

# %%
# initializing ARIMA model
ARIMAmodel = ARIMA(train_85035, order=(2, 0, 1))

# %%
# fit the model
ARIMAmodel = ARIMAmodel.fit()
# Out:
# c:\Users\PC\anaconda3\envs\learn-env\lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "

# %%
# printing the model summary
print(ARIMAmodel.summary())
ARIMAmodel.plot_diagnostics(figsize=(18,18))
plt.show()
# Out:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                    ret   No. Observations:                  120
# Model:                 ARIMA(2, 0, 1)   Log Likelihood                 463.488
# Date:                Fri, 15 Sep 2023   AIC                           -916.976
# Time:                        12:42:11   BIC                           -903.038
# Sample:                    02-01-2005   HQIC                          -911.316
#                          - 01-01-2015
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0042      0.009     -0.454      0.650      -0.022       0.014
# ar.L1          1.0199      0.132      7.703      0.000       0.760       1.279
# ar.L2         -0.0930      0.127     -0.730      0.465      -0.343       0.157
# ma.L1          0.5160      0.111      4.664      0.000       0.299       0.733
# sigma2      2.513e-05   2.53e-06      9.928      0.000    2.02e-05    3.01e-05
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.07   Jarque-Bera (JB):                21.63
# Prob(Q):                              0.80   Prob(JB):                         0.00
# Heteroskedasticity (H):               5.05   Skew:                             0.52
# Prob(H) (two-sided):                  0.00   Kurtosis:                         4.80
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %% [markdown]
# The residuals should exhibit no correlation and should adhere to a normal distribution, meeting the normality assumptions.
#
# Analyzing the QQ-plot in the bottom left, it is evident that the residuals closely align with a linear trend line, indicating their adherence to a normal distribution.
#
# Reviewing the correlogram plot on the bottom left, it is noticeable that there are minimal correlations with their lagged versions, implying the absence of apparent seasonality in the time series data.
#
# Examining the histogram, it reveals a bell curve shape, confirming that the residuals conform to a normal distribution, which is a positive outcome.

# %% [markdown]
# **Testing the model's performance**

# %%
# creating a table of the upper and lower limits
pred = ARIMAmodel.get_prediction(start=pd.to_datetime('2015-02'), end=pd.to_datetime('2018-04'), dynamic=False)
pred_conf = pred.conf_int()
pred_conf.head()
# Out:
#             lower ret  upper ret
# 2015-02-01  -0.007068   0.012584
# 2015-03-01  -0.016075   0.019943
# 2015-04-01  -0.021698   0.024518
# 2015-05-01  -0.025741   0.027646
# 2015-06-01  -0.028850   0.029919

# %% [markdown]
# Plotting the training data against the test data

# %%
# Adjust the figure size
rcParams['figure.figsize'] = 18, 8

# Plot observed values
ax = ts_85035.plot(label='Observed', c="blue")

# Plot predicted values
pred.predicted_mean.plot(ax=ax, label='Prediction', alpha=0.9, c="black")

# Plot the range for confidence intervals
ax.fill_between(pred_conf.index,
                pred_conf.iloc[:, 0],
                pred_conf.iloc[:, 1], color='green', alpha=0.5, label='Confidence level')

# Set axes labels and title
ax.set_xlabel('Date', fontsize=15)
ax.set_ylabel('Returns', fontsize=15)
ax.set_title('Performance of Forecasting Model', fontsize=20)

# Add legend
plt.legend()

# Display the plot
plt.show()

# %% [markdown]
# **Model Evaluation**

# %%
#Getting the rmse for the model
MSE(test_85035,pred.predicted_mean,squared=False)
# Out:
# 0.015501845220760823

# %% [markdown]
# This indicates that our model's monthly returns would be off by 0.0155% if this model is used.

# %% [markdown]
# **Forecasting for the next 3 years**

# %%
# Plug the parameter values from our Auto ARIMA model into a new ARIMA model that fits the entire series.
ARIMA_MODEL = ARIMA(ts_85035, 
                    order=(2,0,1), 
                    enforce_stationarity=False, 
                    enforce_invertibility=False)

# Fit the model and print results
full_output = ARIMA_MODEL.fit()

print(full_output.summary())
# Out:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                    ret   No. Observations:                  159
# Model:                 ARIMA(2, 0, 1)   Log Likelihood                 622.189
# Date:                Sat, 16 Sep 2023   AIC                          -1234.378
# Time:                        11:31:13   BIC                          -1219.096
# Sample:                    02-01-2005   HQIC                         -1228.171
#                          - 04-01-2018
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0001      0.010     -0.012      0.990      -0.019       0.019
# ar.L1          1.0107      0.111      9.141      0.000       0.794       1.227
# ar.L2         -0.0721      0.107     -0.676      0.499      -0.281       0.137
# ma.L1          0.5252      0.091      5.745      0.000       0.346       0.704
# sigma2      2.106e-05   1.75e-06     12.064      0.000    1.76e-05    2.45e-05
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.01   Jarque-Bera (JB):                41.02
# Prob(Q):                              0.91   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.78   Skew:                             0.47
# Prob(H) (two-sided):                  0.04   Kurtosis:                         5.32
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
# Getting a forecast for the next 36 months after the last recorded date on our dataset.
forecast = full_output.get_forecast(36)
future_prediction = forecast.conf_int()
future_prediction['Price'] = forecast.predicted_mean
future_prediction.columns = ['lower','upper','prediction'] 
future_prediction.head()
# Out:
#                lower     upper  prediction
# 2018-05-01  0.001751  0.019741    0.010746
# 2018-06-01 -0.006504  0.026466    0.009981
# 2018-07-01 -0.011884  0.030495    0.009306
# 2018-08-01 -0.015903  0.033260    0.008679
# 2018-09-01 -0.019102  0.035289    0.008094

# %%
# Plotting our Forecast

fig, ax = plt.subplots()
ts_85035.plot(ax=ax,label='Real Values',c="blue")


future_prediction['prediction'].plot(ax=ax,label='predicted value',c="red")

ax.fill_between(x= future_prediction.index, y1= future_prediction['lower'], 
                y2= future_prediction['upper'],color='gray',
                label='Confidence Interval')
ax.legend() 
plt.ylabel("% Home Prices",fontsize=15)
plt.title('Average Monthly Returns - 85035 - With Forecasted Values & Confidence Intervals',fontsize=20)
plt.show()

# %% [markdown]
# **Forecasting for every zipcode**

# %%
zip_predictions = {}

# Creating a for loop to forecast for every zipcode
for i in range(len(df_ts)):

    # selecting every individual series
    series = df_ts[i]["Price"]
    
    #Only taking data from 2011 onwards to more accurately reflect current market conditions
    recent_series = series['2011':]
    
    # Splitting the last 36 months of our series as a test dataset.
    train_series = recent_series[:'2016-04']
    test_series = recent_series['2016-05':]
    
    #Auto ARIMA model
    auto_model = pm.auto_arima(train_series, 
                     trace=True,
                     error_action= 'ignore',
                     suppress_warnings=True,
                     stepwise=True,with_intercept=False)
   
    # Plug the optimal parameter values for our Training data into a SARIMAX model that fits our entire series.
    ARIMA_MODEL = SARIMAX(recent_series, 
                          order= auto_model.order, 
                          seasonal_order= auto_model.seasonal_order, 
                          enforce_stationarity=False, 
                          enforce_invertibility=False)

    # Fit the model and print results
    output = ARIMA_MODEL.fit()

    ## Getting a forecast for the next 36 months after the last absrecorded date on our dataset.
    forecast = output.get_forecast(36)
    prediction = forecast.conf_int()
    prediction['Price'] = forecast.predicted_mean
    prediction.columns = ['lower','upper','prediction'] 
    
    #Adding the Zipcode's ROI to the zip_predictions dictionary
    zip_predictions[df_ts[i]["Zipcode"].unique()[0]] = ((prediction['prediction'][-1])- (series[-1]))/ (series[-1])
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(0,0,0)[0]             : AIC=inf, Time=nan sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=1128.187, Time=0.03 sec
#  ARIMA(1,1,0)(0,0,0)[0]             : AIC=1127.998, Time=0.13 sec
#  ARIMA(0,1,1)(0,0,0)[0]             : AIC=1128.514, Time=0.04 sec
#  ARIMA(2,1,0)(0,0,0)[0]             : AIC=1129.499, Time=0.20 sec
#  ARIMA(1,1,1)(0,0,0)[0]             : AIC=inf, Time=0.31 sec
#  ARIMA(2,1,1)(0,0,0)[0]             : AIC=inf, Time=0.51 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=1088.950, Time=0.30 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=1086.951, Time=0.02 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=1088.950, Time=0.17 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=1079.492, Time=0.41 sec
#  ARIMA(2,1,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.56 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=1074.059, Time=0.42 sec
#  ARIMA(0,1,2)(0,0,0)[0] intercept   : AIC=1090.009, Time=0.25 sec
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=1190.433, Time=0.61 sec
#  ARIMA(1,1,3)(0,0,0)[0] intercept   : AIC=1085.060, Time=0.51 sec
#  ARIMA(0,1,3)(0,0,0)[0] intercept   : AIC=1092.088, Time=0.41 sec
#  ARIMA(2,1,3)(0,0,0)[0] intercept   : AIC=inf, Time=0.64 sec
#  ARIMA(1,1,2)(0,0,0)[0]             : AIC=inf, Time=0.45 sec
#
# Best model:  ARIMA(1,1,2)(0,0,0)[0] intercept
# Total fit time: 6.430 seconds
# Performing stepwise search to minimize aic
#  ARIMA(2,2,2)(0,0,0)[0]             : AIC=1039.010, Time=0.48 sec
#  ARIMA(0,2,0)(0,0,0)[0]             : AIC=1028.674, Time=0.02 sec
#  ARIMA(1,2,0)(0,0,0)[0]             : AIC=1025.075, Time=0.03 sec
#  ARIMA(0,2,1)(0,0,0)[0]             : AIC=1024.273, Time=0.12 sec
#  ARIMA(1,2,1)(0,0,0)[0]             : AIC=1026.272, Time=0.26 sec
#  ARIMA(0,2,2)(0,0,0)[0]             : AIC=1026.271, Time=0.14 sec
#  ARIMA(1,2,2)(0,0,0)[0]             : AIC=inf, Time=0.30 sec
#  ARIMA(0,2,1)(0,0,0)[0] intercept   : AIC=1026.196, Time=0.13 sec
#
# Best model:  ARIMA(0,2,1)(0,0,0)[0]
# Total fit time: 1.487 seconds
# Performing stepwise search to minimize aic
#  ARIMA(2,2,2)(0,0,0)[0]             : AIC=1122.469, Time=0.08 sec
#  ARIMA(0,2,0)(0,0,0)[0]             : AIC=1102.933, Time=0.01 sec
#  ARIMA(1,2,0)(0,0,0)[0]             : AIC=1104.628, Time=0.04 sec
#  ARIMA(0,2,1)(0,0,0)[0]             : AIC=1103.916, Time=0.11 sec
#  ARIMA(1,2,1)(0,0,0)[0]             : AIC=1108.756, Time=0.06 sec
#  ARIMA(0,2,0)(0,0,0)[0] intercept   : AIC=1104.860, Time=0.03 sec
#
# Best model:  ARIMA(0,2,0)(0,0,0)[0]
# Total fit time: 0.335 seconds
# Performing stepwise search to minimize aic
#  ARIMA(2,2,2)(0,0,0)[0]             : AIC=inf, Time=0.58 sec
#  ARIMA(0,2,0)(0,0,0)[0]             : AIC=1091.763, Time=0.02 sec
#  ARIMA(1,2,0)(0,0,0)[0]             : AIC=1099.319, Time=0.03 sec
#  ARIMA(0,2,1)(0,0,0)[0]             : AIC=1109.099, Time=0.03 sec
#  ARIMA(1,2,1)(0,0,0)[0]             : AIC=1114.150, Time=0.16 sec
#  ARIMA(0,2,0)(0,0,0)[0] intercept   : AIC=1093.748, Time=0.01 sec
#
# Best model:  ARIMA(0,2,0)(0,0,0)[0]
# Total fit time: 0.832 seconds
# Performing stepwise search to minimize aic
#  ARIMA(2,2,2)(0,0,0)[0]             : AIC=891.901, Time=0.30 sec
#  ARIMA(0,2,0)(0,0,0)[0]             : AIC=885.881, Time=0.02 sec
#  ARIMA(1,2,0)(0,0,0)[0]             : AIC=886.696, Time=0.04 sec
#  ARIMA(0,2,1)(0,0,0)[0]             : AIC=886.611, Time=0.03 sec
#  ARIMA(1,2,1)(0,0,0)[0]             : AIC=888.481, Time=0.15 sec
#  ARIMA(0,2,0)(0,0,0)[0] intercept   : AIC=887.303, Time=0.03 sec
#
# Best model:  ARIMA(0,2,0)(0,0,0)[0]
# Total fit time: 0.583 seconds

# %% [markdown]
# **Conclusion And Recommendation**

# %%
# Get the top five zipcodes with the highest ROI
top_zipcodes = sorted(zip_predictions, key=zip_predictions.get, reverse=True)[:5]

# Create a list of ROI values for the top five zipcodes
roi_values = [zip_predictions[zipcode] for zipcode in top_zipcodes]

# Create a bar graph of the top five zipcodes and their corresponding ROI values
plt.bar(top_zipcodes, roi_values)
plt.xlabel('Zipcode',fontsize=15)
plt.ylabel('ROI',fontsize=15)
plt.title('Top Five Zipcodes with Highest ROI Forecast',fontsize=20)
plt.show()

# %% [markdown]
# Based on the graph above, the zipcode 94804 has the highest ROI forecast. Therefore, it would be advantageous for the investor to consider investing in this zipcode.

# %%
zip_roi_dict = {zipcode: zip_predictions[zipcode] for zipcode in top_zipcodes}

# Convert the dictionary to a pandas dataframe and sort it by ROI values in descending order
zip_roi_df = pd.DataFrame.from_dict(zip_roi_dict, orient='index', columns=['% ROI'])
zip_roi_df = zip_roi_df.sort_values(by='% ROI', ascending=False)

# Print the dataframe
zip_roi_df.index.name = "Zipcode"
zip_roi_df
# Out:
#             % ROI
# Zipcode
# 94804    0.842062
# 94590    0.414785
# 94601    0.298571
# 85008    0.091814
# 85035    0.000000

# %% [markdown]
# All the Zipcodes show promising predicted prices, with positive returns, except for the 85035 zipcode.
#
# Given the information presented in the graph above, we can provide our top five recommendations along with their expected ROI after three years.
#
# Investors can make informed decisions by considering any of the suggested zipcodes, except for 85035, which does not yield a positive return on investment.
